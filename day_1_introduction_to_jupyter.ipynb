# %% [markdown]
# # introduction_to_jupyter

# %%
# type of cell
# 1.code---write the code (program)
# 2.markdown---headings with formatate
# 3.raw----raw text without formate

# %%
print("hello world")
# Out:
# hello world

# %%
"formatting"
# Out:
# 'formatting'

# %% [markdown]
# how to give heading

# %% [markdown]
# # hello

# %% [markdown]
# ## hello

# %% [markdown]
# #### hello

# %% [markdown]
# #### hello

# %% [markdown]
# ##### hello

# %% [markdown]
# ###### hello

# %% [markdown]
# **hello guys**

# %% [markdown]
# *how to write in italic*

# %% [markdown]
# ***such a nice day***

# %% [markdown]
# # *hello*

# %% [markdown]
# unordered list

# %% [markdown]
# - first_day
# - second_day
# - third_day

# %% [markdown]
# # ordered list

# %% [markdown]
# 1. first_day
# 2. second_day
# 3. third_day
